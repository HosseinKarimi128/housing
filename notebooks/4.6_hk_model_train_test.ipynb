# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
housing_prepared = pd.read_csv("C:/Users\h.karimi\Documents\pprojects\housing_hw\data\interim/preprocessed_data_x_train.csv")
housing_labels = pd.read_csv("C:/Users\h.karimi\Documents\pprojects\housing_hw\data\interim/preprocessed_data_y_train.csv")
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression()

# %%
print("Predictions:", lin_reg.predict(housing_prepared))
# Out:
# Predictions: [[151161.69288461]
#  [136100.75878827]
#  [220770.20669988]
#  [145895.31011365]
#  [168774.86076909]
#  [102640.68161861]
#  [153020.39378426]
#  [384238.90124806]
#  [256905.27310466]
#  [224991.00878617]
#  [195580.80684721]
#  [312141.44820743]
#  [181352.50615606]
#  [204509.58727096]
#  [228027.0253697 ]
#  [ 87561.25545312]
#  [ 44763.68448634]
#  [174027.76459417]
#  [473827.37790488]
#  [ 91809.27639725]
#  [108342.55145348]
#  [137544.59467315]
#  [181795.60557993]
#  [149188.82781651]
#  [207900.94771866]
#  [154823.85880533]
#  [230340.16313281]
#  [124264.93593058]
#  [183485.86277571]
#  [ 77973.05050718]
#  [141574.69046402]
#  [289142.43852906]
#  [127775.219336  ]
#  [149492.4394661 ]
#  [206768.88547941]
#  [110961.38399551]
#  [237215.97695828]
#  [161473.39575699]
#  [132716.9081426 ]
#  [189786.03768093]
#  [205513.32916259]
#  [ 91844.66394425]
#  [196020.20657441]
#  [186933.53332026]
#  [157120.85699607]
#  [140380.77844541]
#  [191826.16842358]
# ...

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
housing_predictions = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 18886.747315892007

# %%
from sklearn.metrics import mean_absolute_percentage_error
lin_mape =  mean_absolute_percentage_error(housing_labels, housing_predictions)
lin_mape
# Out:
# 0.07034190603342838

# %%
housing_prepared = pd.read_csv("C:/Users\h.karimi\Documents\pprojects\housing_hw\data\interim/preprocessed_data_x_test.csv")
housing_labels = pd.read_csv("C:/Users\h.karimi\Documents\pprojects\housing_hw\data\interim/preprocessed_data_y_test.csv")
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
housing_predictions = lin_reg.predict(housing_prepared)
lin_mape = mean_absolute_percentage_error(housing_labels, housing_predictions)
lin_mape
# Out:
# 0.06632656206790277
